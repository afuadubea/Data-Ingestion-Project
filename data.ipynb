# %%
import pandas as pd
import os
import boto3

# %%
pip install boto3
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.5.0 requires botocore<1.29.77,>=1.29.76, but you have botocore 1.34.115 which is incompatible.
# ...
#
#   Obtaining dependency information for boto3 from https://files.pythonhosted.org/packages/70/a9/96627b82b883f6b9f6a5dcbcc1571d57bd5696f69846f2df78a42b46f18f/boto3-1.34.115-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for botocore<1.35.0,>=1.34.115 from https://files.pythonhosted.org/packages/2e/6d/1c4302be80ae8c9f772173d4734f956dbcd7625bb628406d8aed8705c6c3/botocore-1.34.115-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for s3transfer<0.11.0,>=0.10.0 from https://files.pythonhosted.org/packages/83/37/395cdb6ee92925fa211e55d8f07b9f93cf93f60d7d4ce5e66fd73f1ea986/s3transfer-0.10.1-py3-none-any.whl.metadata
# ...

# %%
#file path with the name and it's file extension 
file_path = r"C:\Users\DELL\Downloads\Capstone Project\ebay_womens_perfume.csv"

# Read the CSV file into a DataFrame
Wparfumes = pd.read_csv(file_path)
Wparfumes
# Out:
#                   brand                                              title  \
# 0      Carolina Herrera  Good Girl by Carolina Herrera 2.7 oz Eau De Pa...
# 1              As Shown  Parfums de Marly Delina La Rosee Eau de Parfum...
# 2                 PRADA  PRADA Paradoxe by Prada EDP 3.0oz/90ml Spray P...
# 3               As Show  J'adore Parfum D'eau by Christian 3.4 oz EDP F...
# 4               Khadlaj  Shiyaaka for Men EDP Spray 100ML (3.4 FL.OZ) B...
# ..                  ...                                                ...
# 995                Avon  Avon Far Away Infinity Eau de Parfum 1.7 fl. o...
# 996             Mancera  Roses Greedy by Mancera perfume for unisex EDP...
# 997           Unbranded  Sweet Tooth Eau de Parfum, Perfume for Women, ...
# 998  Juliette Has A Gun  MMMM BY Juliette Has A Gun perfume for her EDP...
# 999        Paris Hilton  PARIS HILTON ELECTRIFY for Women Cologne 3.4 o...
#
#                type  price priceWithCurrency  available  \
# ...

# %%
#file path with the name and it's file extension 
file_path = r"C:\Users\DELL\Downloads\Capstone Project\ebay_mens_perfume.csv"

# Read the CSV file into a DataFrame
Mparfumes = pd.read_csv(file_path)
Mparfumes
# Out:
#               brand                                              title  \
# 0              Dior  Christian Dior Sauvage Men's EDP 3.4 oz Fragra...
# 1           AS SHOW  A-v-entus Eau de Parfum 3.3 oz 100ML Millesime...
# 2         Unbranded                   HOGO BOSS cologne For Men 3.4 oz
# 3    Giorgio Armani  Acqua Di Gio by Giorgio Armani 6.7 Fl oz Eau D...
# 4           Lattafa  Lattafa Men's Hayaati Al Maleky EDP Spray 3.4 ...
# ..              ...                                                ...
# 995           GUESS  Guess 1981 by Guess cologne for men EDT 3.3 / ...
# 996           Armaf  Club de Nuit Intense by Armaf cologne for men ...
# 997    Paco Rabanne  Invictus by Paco Rabanne for Men EDT Spray 3.4...
# 998          Lomani  Lomani EDT Cologne 3.4 oz Men - Authentic, Bra...
# 999    Estee Lauder  Beyond Paradise by Estee Lauder for Men Cologn...
#
#                 type   price priceWithCurrency  available  \
# ...

# %%
import boto3

# Initialize a session using Amazon S3
session = boto3.Session("AKIAQ3EGPG6GQKAYFWME", "")
s3 = boto3.client('s3')

# Function to upload CSV to S3
def upload_csv_to_s3(file_name, bucket_name, object_name):
    with open(file_name, "rb") as f:
        s3.upload_fileobj(f, bucket_name, object_name)

# File names and paths
file_name1 = r'C:\Users\DELL\Downloads\Capstone Project\ebay_womens_perfume.csv'
file_name2  = r'C:\Users\DELL\Downloads\Capstone Project\ebay_mens_perfume.csv'

# Bucket name and object names (keys)
bucket_name = 'testbucketting02'
object_name1 = 'womenperfume'
object_name2 = 'menperfume'

# Upload CSV files
upload_csv_to_s3(file_name1, bucket_name, object_name1)
upload_csv_to_s3(file_name2, bucket_name, object_name2)

print(f"{file_name1} uploaded to {bucket_name}/{object_name1}")
print(f"{file_name2} uploaded to {bucket_name}/{object_name2}")
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Cell In[9], line 22
#      19 object_name2 = 'menperfume'
#      21 # Upload CSV files
# ---> 22 upload_csv_to_s3(file_name1, bucket_name, object_name1)
#      23 upload_csv_to_s3(file_name2, bucket_name, object_name2)
#      25 print(f"{file_name1} uploaded to {bucket_name}/{object_name1}")
#
# Cell In[9], line 10, in upload_csv_to_s3(file_name, bucket_name, object_name)
#       8 def upload_csv_to_s3(file_name, bucket_name, object_name):
#       9     with open(file_name, "rb") as f:
# ---> 10         s3.upload_fileobj(f, bucket_name, object_name)
#
# File ~\anaconda3\Lib\site-packages\boto3\s3\inject.py:642, in upload_fileobj(self, Fileobj, Bucket, Key, ExtraArgs, Callback, Config)
#     634 with create_transfer_manager(self, config) as manager:
#     635     future = manager.upload(
#     636         fileobj=Fileobj,
# ...

# %%
#pip install --upgrade mysql-connector-python
import mysql.connector

# %%
from sqlalchemy import create_engine

def import_files_to_mysql(engine, folder_path):
    folder_path = r"C:\Users\DELL\Downloads\Capstone Project"
    files = os.listdir(folder_path)
    for file_name in files:
        table_name = os.path.splitext(file_name)[0]
        file_path = os.path.join(folder_path, file_name)
        
        if os.path.isfile(file_path):
            try:
                if file_name.endswith('.csv'):
                    df = pd.read_csv(file_path)
                elif file_name.endswith('.json'):
                    df = pd.read_json(file_path)
                else:
                    print(f"Unsupported file format: {file_name}")
                    continue

                df.to_sql(table_name, engine, if_exists='replace', index=False)
                print(f"Table '{table_name}' imported successfully.")
            except Exception as e:
                print(f"Error importing file '{file_name}': {e}")

def main():
    user_name = 'root'
    user_password = 'cod.xAel_05*000'
    database = 'ecommerce_parfume'
    host_name = 'localhost'
    folder_path = r"C:\Users\DELL\Downloads\Capstone Project"

    # Create SQLAlchemy engine
    engine = create_engine(f"mysql+mysqlconnector://{user_name}:{user_password}@{host_name}/{database}")

    import_files_to_mysql(engine, folder_path)

    print("Connection closed")

if __name__ == "__main__":
    main()
# Out:
# Table 'ebay_mens_perfume' imported successfully.
# Table 'ebay_womens_perfume' imported successfully.
# Unsupported file format: projectslides.txt
# Unsupported file format: S3_data_ingestion.py
# Unsupported file format: Untitled.ipynb
# Connection closed
